# %% [markdown]
# # Reto 3 – Análisis de contaminantes
# En este cuaderno se realizará el análisis de los datos de calidad del aire.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar datos
df = pd.read_csv('data/tu_archivo.csv')
df.head()
